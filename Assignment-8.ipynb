# %% [markdown]
# ## 1. Counting the white spaces in a string

# %%
string = "P r og ram in g"
print(string.count(" "))
# Out:
# 5

# %% [markdown]
# ## 2. Counting Digits, Letters, and Spaces in a string

# %%
# importing regular expression library
import re
name = "python is 1"
digitCount = re.sub("[^0-9]", "", name)
letterCount = re.sub("[^a-zA-Z]", "", name)
spaceCount = re.findall("[\s]", name)
print(len(digitCount))
print(len(letterCount))
print(len(spaceCount))
# Out:
# 1
# 8
# 2

# %% [markdown]
# ## 3. Removing All Whitespace in a string

# %%
string = "P y t h o n"
string2 = string.replace(" ", "")
print(string2)
# Out:
# Python

# %% [markdown]
# ## 4. Randomizing the items of a list in Python

# %%
from random import shuffle
lst = ["python ", "is", "easy"]
shuffle(lst)
print(lst)
# Out:
# ['python ', 'easy', 'is']

# %% [markdown]
# ## 5. Write a python program that removes duplicate elements from a list while keeping the original order ?

# %%
items = [1, 2, 3, 1, 2]
unique_items = []
for i in items:
    if i not in unique_items:
        unique_items.append(i)
print(unique_items)
# Out:
# [1, 2, 3]

# %%
# method-2
items = [1, 2, 3, 1, 2]
print(list(dict.fromkeys(items)))
# Out:
# [1, 2, 3]
